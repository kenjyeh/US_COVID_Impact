# %%
from census import Census
import gmaps
import numpy as np
import pandas as pd
import requests
import time
from scipy.stats import stats
from matplotlib import pyplot as plt 
from scipy.stats import linregress
from sklearn import datasets

# %%
#States import
df1 = pd.read_csv('csvData.csv')
State1 = pd.DataFrame(df1) 
State1 = State1.drop([8])
State1.head()
# Out:
#         State  Abbrev Code
# 0     Alabama    Ala.   AL
# 1      Alaska  Alaska   AK
# 2     Arizona   Ariz.   AZ
# 3    Arkansas    Ark.   AR
# 4  California  Calif.   CA

# %%
#Corona data import 
df = pd.read_csv('united_states_covid19_cases_and_deaths_by_state.csv')
coronadata = pd.DataFrame(df)
coronadata = coronadata.drop(columns=['Confirmed Cases', 'Probable Cases','Cases in Last 7 Days','Case Rate per 100000','Confirmed Deaths', 'Probable Deaths','Deaths in Last 7 Days','Case Rate per 100000 in Last 7 Days'])

# %%
#coronadata = coronadata.drop([3,8,11,13,28,34,44,45,47,54,60]) 
coronadata = coronadata.rename(columns={"State/Territory":"State"})   

coronadata
# Out:
#                        State  Total Cases  Total Deaths  \
# 0                     Alaska        51693           257
# 1                    Alabama       443009          6662
# 2                   Arkansas       284702          4650
# 3             American Samoa            3             0
# 4                    Arizona       727895         12239
# ..                       ...          ...           ...
# 56                Washington       302141          4148
# 57                 Wisconsin       582477          6199
# 58             West Virginia       115839          1899
# 59                   Wyoming        51022           571
# 60  United States of America     25152433        419827
#
#     Death Rate per 100000  Death Rate per 100K in Last 7 Days
# 0                      35                                 0.6
# 1                     135                                 1.6
# 2                     154                                 1.5
# 3                       0                                 0.0
# 4                     168                                 1.9
# ..                    ...                                 ...
# 56                     54                                 0.5
# 57                    106                                 0.7
# 58                    105                                 0.9
# 59                     98                                 1.2
# 60                    126                                 0.9
#
# [61 rows x 5 columns]

# %%
Coronastate = pd.merge(coronadata,State1,how="left",on=['State','State'])
Coronastate = Coronastate.drop(columns = {'Total Deaths','Death Rate per 100000',"Death Rate per 100K in Last 7 Days"}) 
Coronastate.head()
# Out:
#             State  Total Cases  Abbrev Code
# 0          Alaska        51693  Alaska   AK
# 1         Alabama       443009    Ala.   AL
# 2        Arkansas       284702    Ark.   AR
# 3  American Samoa            3     NaN  NaN
# 4         Arizona       727895   Ariz.   AZ

# %%
#Obestity import 
df = pd.read_csv('National_Obesity_By_State.csv')
Obesity = pd.DataFrame(df) 
Obesity = Obesity.rename(columns={"NAME":"State"}) 
Obesity.head()
# Out:
#    FID       State  Obesity  SHAPE_Length    SHAPE_Area
# 0    1       Texas     32.4  1.540832e+07  7.672329e+12
# 1    2  California     24.2  1.451870e+07  5.327809e+12
# 2    3    Kentucky     34.6  6.346699e+06  1.128830e+12
# 3    4     Georgia     30.7  5.795596e+06  1.652980e+12
# 4    5   Wisconsin     30.7  6.806782e+06  1.567816e+12

# %%
df1 = pd.read_csv('csvData.csv')
State = pd.DataFrame(df1) 
State.head()
# Out:
#         State  Abbrev Code
# 0     Alabama    Ala.   AL
# 1      Alaska  Alaska   AK
# 2     Arizona   Ariz.   AZ
# 3    Arkansas    Ark.   AR
# 4  California  Calif.   CA

# %%
ObseityFrame = pd.merge(
    Obesity, State, how="left", on=["State", "State"])

# %%
ObseityFrame.rename(columns={"Code": "State","State":"Name","Obesity":"Obesity (BMI)"}) 
ObseityFrame.head()
# Out:
#    FID       State  Obesity  SHAPE_Length    SHAPE_Area  Abbrev Code
# 0    1       Texas     32.4  1.540832e+07  7.672329e+12    Tex.   TX
# 1    2  California     24.2  1.451870e+07  5.327809e+12  Calif.   CA
# 2    3    Kentucky     34.6  6.346699e+06  1.128830e+12     Ky.   KY
# 3    4     Georgia     30.7  5.795596e+06  1.652980e+12     Ga.   GA
# 4    5   Wisconsin     30.7  6.806782e+06  1.567816e+12    Wis.   WI

# %%
FinalFrame = pd.merge(
    ObseityFrame, Coronastate, how="left", on=["State", "State"]) 
ObseityFrame.head()
# Out:
#    FID       State  Obesity  SHAPE_Length    SHAPE_Area  Abbrev Code
# 0    1       Texas     32.4  1.540832e+07  7.672329e+12    Tex.   TX
# 1    2  California     24.2  1.451870e+07  5.327809e+12  Calif.   CA
# 2    3    Kentucky     34.6  6.346699e+06  1.128830e+12     Ky.   KY
# 3    4     Georgia     30.7  5.795596e+06  1.652980e+12     Ga.   GA
# 4    5   Wisconsin     30.7  6.806782e+06  1.567816e+12    Wis.   WI

# %%
ObesityFrame = ObseityFrame.drop(columns=['SHAPE_Length', 'SHAPE_Area','Abbrev','FID']) 
ObesityFrame = ObesityFrame.drop(38)    
ObesityFrame.head()
# Out:
#         State  Obesity Code
# 0       Texas     32.4   TX
# 1  California     24.2   CA
# 2    Kentucky     34.6   KY
# 3     Georgia     30.7   GA
# 4   Wisconsin     30.7   WI

# %%
ObesityFrame= ObesityFrame.rename(columns={"Code": "State","Obesity":"Obesity (BMI)"}) 
ObesityFrame = ObesityFrame.drop([35])

# %%
ObesityFrame.head()
# Out:
#         State  Obesity (BMI) State
# 0       Texas           32.4    TX
# 1  California           24.2    CA
# 2    Kentucky           34.6    KY
# 3     Georgia           30.7    GA
# 4   Wisconsin           30.7    WI

# %%
FinalFrame = pd.merge(
    ObseityFrame, Coronastate, how="left", on=["State", "State"]) 
FinalFrame = FinalFrame.drop(columns=['SHAPE_Length', 'SHAPE_Area','Abbrev_x','Abbrev_y','Code_x','Code_y','FID']) 
FinalFrame = FinalFrame.drop([51,35,38]) 
FinalFrame
# Out:
#              State  Obesity  Total Cases
# 0            Texas     32.4      2246845
# 1       California     24.2      3136158
# 2         Kentucky     34.6       347836
# 3          Georgia     30.7       870828
# 4        Wisconsin     30.7       582477
# 5           Oregon     30.1       138587
# 6         Virginia     29.2       483326
# 7        Tennessee     33.8       710427
# 8        Louisiana     36.2       385942
# 9         New York     25.0       772569
# 10        Michigan     31.2       600093
# 11           Idaho     28.6       160033
# 12         Florida     26.8      1627830
# 13          Alaska     29.8        51693
# 14         Montana     23.6        91816
# 15       Minnesota     26.1       455783
# 16        Nebraska     31.4       187793
# 17      Washington     26.4       302141
# 18            Ohio     29.8       868656
# 19        Illinois     30.8      1104763
# 20        Missouri     32.4       450414
# 21            Iowa     32.1       313515
# 22    South Dakota     30.4       107180
# 23        Arkansas     34.5       284702
# 24     Mississippi     35.6       266598
# 25        Colorado     20.2       387462
# 26  North Carolina     30.1       723445
# 27            Utah     24.5       337264
# 28        Oklahoma     33.9       380647
# 29         Wyoming     29.0        51022
# 30   West Virginia     35.6       115839
# 31         Indiana     31.3       613228
# 32   Massachusetts     24.3       489298
# 33          Nevada     26.7       271897
# 34     Connecticut     25.3       243632
# 36    Rhode Island     26.0       111754
# 37         Alabama     35.6       443009
# 39  South Carolina     31.7       421417
# 40           Maine     30.0        37708
# 41          Hawaii     22.7        24587
# 42         Arizona     28.4       727895
# 43      New Mexico     28.8       169696
# 44        Maryland     28.9       344620
# 45        Delaware     29.7        75191
# 46    Pennsylvania     30.0       807867
# 47          Kansas     34.2       269255
# 48         Vermont     25.1        11165
# 49      New Jersey     25.6       666951
# 50    North Dakota     31.0        97006

# %%
y_values = FinalFrame['Total Cases']
x_values = FinalFrame['Obesity']

# %%
# Histogram Plot of Data
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Obesity')
plt.ylabel('Total Cases')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.006154583499523735

# %%
stats.ttest_ind(x_values, y_values, equal_var=False)

# %%
FinalFrame = FinalFrame.set_index("State")

# %%
count_chart = FinalFrame.plot(kind='bar', figsize=(10, 11),width=1)

# Set the xlabel and ylabel using class methods
count_chart.set_xlabel("State")
count_chart.set_ylabel("Covid Deaths")


plt.show()
plt.tight_layout() 


count_chart = FinalFrame['Obesity'].plot(kind='bar', figsize=(10, 2),width=1)

# Set the xlabel and ylabel using class methods
count_chart.set_xlabel("State")
count_chart.set_ylabel("Obesity (BMI)")


plt.show()
plt.tight_layout()

# %%
t = np.arange(0.01, 10.0, 0.01)
data1 = np.exp(t)
data2 = np.sin(2 * np.pi * t)

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('time (s)')
ax1.set_ylabel('exp', color=color)
ax1.plot(t, data1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('sin', color=color)  # we already handled the x-label with ax1
ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()
