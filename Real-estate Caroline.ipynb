# %%
# Dependencies and Setup
# %matplotlib notebook
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
import datetime

#Zillow API
#X1-ZWz1i6oiwod2bv_634pb

# %%
#Read weekly housing data from Redfin
#Google Drive for reference: 
redfinfile = "weekly_housing_market_data_most_recent.tsv"
housing_redfin_all = pd.read_csv(redfinfile,delimiter = '\t')
housing_redfin_all
# Out:
#         region_id  region_type_id                    region_name region_type  \
# 0            1885               5             Grafton County, NH      county
# 1             757               5            Kankakee County, IL      county
# 2             757               5            Kankakee County, IL      county
# 3           33340              -2       Milwaukee, WI metro area       metro
# 4             819               5               Boone County, IN      county
# ...           ...             ...                            ...         ...
# 996150       1124               5             Bullitt County, KY      county
# 996151       1895               5            Cape May County, NJ      county
# 996152        867               5          Montgomery County, IN      county
# 996153        495               5            Seminole County, FL      county
# 996154      38940              -2  Port St. Lucie, FL metro area       metro
#
#        period_begin  period_end  duration  total_homes_sold  \
# 0        2020-01-20  2020-01-26   1 weeks              13.0
# 1        2019-05-06  2019-05-12   1 weeks              25.0
# 2        2020-10-19  2020-10-25   1 weeks              21.0
# 3        2017-08-28  2017-09-03   1 weeks             650.0
# 4        2019-01-07  2019-01-13   1 weeks              15.0
# ...             ...         ...       ...               ...
# 996150   2017-12-25  2018-03-18  12 weeks             218.0
# 996151   2017-08-21  2017-11-12  12 weeks             934.0
# 996152   2018-01-15  2018-04-08  12 weeks              82.0
# 996153   2018-07-09  2018-09-30  12 weeks            2151.0
# 996154   2020-03-16  2020-06-07  12 weeks            2353.0
#
#         total_homes_sold_yoy  average_homes_sold  ...  \
# 0                   1.166667                13.0  ...
# 1                   0.136364                25.0  ...
# 2                  -0.160000                21.0  ...
# 3                   0.074380               650.0  ...
# 4                   0.500000                15.0  ...
# ...                      ...                 ...  ...
# 996150             -0.018018                18.0  ...
# 996151             -0.018908                77.0  ...
# 996152             -0.068182                 6.0  ...
# 996153              0.075500               179.0  ...
# 996154             -0.196654               196.0  ...
#
#         median_days_on_market_yoy  pending_sales_to_sales_ratio  \
# 0                           -29.5                      0.538462
# 1                           -53.5                      0.680000
# 2                           -19.0                      1.380952
# 3                            -8.0                      0.596923
# 4                             8.5                      0.533333
# ...                           ...                           ...
# 996150                        6.8                      0.812189
# 996151                      -31.8                      0.494829
# 996152                      -17.2                      1.033333
# 996153                        0.1                      0.749268
# 996154                       -7.3                      0.601066
#
#         pending_sales_to_sales_ratio_yoy  months_of_supply  \
# 0                              -0.461538         40.076923
# 1                               0.361818         14.720000
# 2                               0.940952         12.619048
# 3                               0.046510         11.441538
# 4                              -0.366667         16.600000
# ...                                  ...               ...
# 996150                         -0.184020         14.814671
# 996151                          0.078504         30.696681
# 996152                          0.096176         19.466071
# 996153                         -0.001147         11.454032
# 996154                          0.010019         22.752191
#
#         months_of_supply_yoy  average_pending_sales_listing_updates  \
# 0                 -63.923077                                   37.0
# 1                  -2.689091                                   35.0
# 2                  -3.500952                                   41.0
# 3                  -1.927057                                  605.0
# 4                  -9.000000                                   16.0
# ...                      ...                                    ...
# 996150             -1.625127                                   31.0
# 996151             -5.052415                                   85.0
# 996152             -6.454431                                   12.0
# 996153             -1.085844                                  197.0
# 996154              1.908252                                  286.0
#
#         average_pending_sales_listing_updates_yoy  \
# 0                                        0.088235
# 1                                        0.346154
# 2                                        0.782609
# 3                                        2.055556
# 4                                       -0.200000
# ...                                           ...
# 996150                                  -0.060606
# 996151                                  -0.011628
# 996152                                  -0.142857
# 996153                                   0.076503
# 996154                                  -0.166181
#
#         percent_total_price_drops_of_inventory  \
# 0                                     0.018000
# 1                                     0.048851
# 2                                     0.052174
# 3                                     0.041734
# 4                                     0.061674
# ...                                        ...
# 996150                                0.219828
# 996151                                0.381168
# 996152                                0.339623
# 996153                                1.029526
# 996154                                0.389671
#
#         percent_total_price_drops_of_inventory_yoy         last_updated
# 0                                         0.004644  2021-01-20 14:55:38
# 1                                        -0.019084  2021-01-20 14:55:38
# 2                                         0.002436  2021-01-20 14:55:38
# 3                                         0.005552  2021-01-20 14:55:38
# 4                                         0.015064  2021-01-20 14:55:38
# ...                                            ...                  ...
# 996150                                   -0.060172  2021-01-20 14:55:38
# 996151                                    0.012277  2021-01-20 14:55:38
# 996152                                   -0.123064  2021-01-20 14:55:38
# 996153                                    0.192893  2021-01-20 14:55:38
# 996154                                   -0.179342  2021-01-20 14:55:38
#
# [996155 rows x 78 columns]

# %%
#Only selecting the period_begin starting from 2020-1-1
housing_redfin_all["period_begin"]=pd.to_datetime(housing_redfin_all["period_begin"])

#Keeping the data starting from 2020-1-1
housing_redfin = housing_redfin_all[(housing_redfin_all["period_begin"]>'2020-1-1')]

#reset index
housing_redfin = housing_redfin.reset_index()
housing_redfin

#Save to csv
#housing_redfin.to_csv('housing_redfin.csv')
