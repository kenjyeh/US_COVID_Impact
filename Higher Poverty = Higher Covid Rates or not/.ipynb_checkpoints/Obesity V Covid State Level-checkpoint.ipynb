# %%
from census import Census
import gmaps
import numpy as np
import pandas as pd
import requests
import time
from scipy.stats import stats
from matplotlib import pyplot as plt 
from scipy.stats import linregress
from sklearn import datasets

# %%
#States import
df1 = pd.read_csv('csvData.csv')
State1 = pd.DataFrame(df1) 
State1 = State1.drop([8])
State1.head()
# Out:
#         State  Abbrev Code
# 0     Alabama    Ala.   AL
# 1      Alaska  Alaska   AK
# 2     Arizona   Ariz.   AZ
# 3    Arkansas    Ark.   AR
# 4  California  Calif.   CA

# %%
#Corona data import 
df = pd.read_csv('united_states_covid19_cases_and_deaths_by_state.csv')
coronadata = pd.DataFrame(df)
coronadata = coronadata.drop(columns=['Confirmed Cases', 'Probable Cases','Cases in Last 7 Days','Case Rate per 100000','Confirmed Deaths', 'Probable Deaths','Deaths in Last 7 Days','Case Rate per 100000 in Last 7 Days'])

# %%
#coronadata = coronadata.drop([3,8,11,13,28,34,44,45,47,54,60]) 
coronadata = coronadata.rename(columns={"State/Territory":"State"})   

coronadata
# Out:
#              State  Total Cases  Total Deaths  Death Rate per 100000  \
# 0           Alaska        51693           257                     35
# 1          Alabama       443009          6662                    135
# 2         Arkansas       284702          4650                    154
# 4          Arizona       727895         12239                    168
# 5       California      3136158         37118                     93
# 6         Colorado       387462          5512                     95
# 7      Connecticut       243632          6911                    193
# 9         Delaware        75191          1049                    107
# 10         Florida      1627830         25446                    118
# 12         Georgia       870828         13303                    125
# 14          Hawaii        24587           339                     23
# 15            Iowa       313515          4488                    142
# 16           Idaho       160033          1681                     94
# 17        Illinois      1104763         20744                    163
# 18         Indiana       613228          9728                    144
# 19          Kansas       269255          3622                    124
# 20        Kentucky       347836          3460                     77
# 21       Louisiana       385942          8590                    184
# 22   Massachusetts       489298         14097                    204
# 23        Maryland       344620          6963                    115
# 24           Maine        37708           558                     41
# 25        Michigan       600093         15219                    152
# 26       Minnesota       455783          6166                    109
# 27        Missouri       450414          6553                    106
# 29     Mississippi       266598          5852                    196
# 30         Montana        91816          1151                    107
# 31  North Carolina       723445          8720                     83
# 32    North Dakota        97006          1415                    185
# 33        Nebraska       187793          1894                     97
# 35      New Jersey       666951         20972                    236
# 36      New Mexico       169696          3157                    150
# 37          Nevada       271897          4029                    130
# 38        New York       772569         15618                    141
# 39   New York City       582175         26720                    318
# 40            Ohio       868656         10768                     92
# 41        Oklahoma       380647          3333                     84
# 42          Oregon       138587          1882                     44
# 43    Pennsylvania       807867         20664                    161
# 46    Rhode Island       111754          2110                    199
# 48  South Carolina       421417          6552                    127
# 49    South Dakota       107180          1705                    192
# 50       Tennessee       710427          8970                    131
# 51           Texas      2246845         34394                    118
# 52            Utah       337264          1597                     49
# 53        Virginia       483326          6174                     72
# 55         Vermont        11165           171                     27
# 56      Washington       302141          4148                     54
# 57       Wisconsin       582477          6199                    106
# 58   West Virginia       115839          1899                    105
# 59         Wyoming        51022           571                     98
#
#     Death Rate per 100K in Last 7 Days
# 0                                  0.6
# 1                                  1.6
# 2                                  1.5
# 4                                  1.9
# 5                                  1.3
# 6                                  0.3
# 7                                  1.0
# 9                                  0.5
# 10                                 0.8
# 12                                 1.3
# 14                                 0.2
# 15                                 0.7
# 16                                 0.6
# 17                                 0.7
# 18                                 0.8
# 19                                 0.5
# 20                                 0.9
# 21                                 1.0
# 22                                 1.0
# 23                                 0.7
# 24                                 0.4
# 25                                 0.8
# 26                                 0.4
# 27                                 0.7
# 29                                 1.3
# 30                                 0.8
# 31                                 0.8
# 32                                 0.5
# 33                                 0.4
# 35                                 0.8
# 36                                 1.4
# 37                                 1.1
# 38                                 1.0
# 39                                 1.0
# 40                                 0.6
# 41                                 1.0
# 42                                 0.3
# 43                                 1.4
# 46                                 1.4
# 48                                 0.8
# 49                                 0.6
# 50                                 1.1
# 51                                 1.1
# 52                                 0.4
# 53                                 0.6
# 55                                 0.2
# 56                                 0.5
# 57                                 0.7
# 58                                 0.9
# 59                                 1.2

# %%
Coronastate = pd.merge(coronadata,State1,how="left",on=['State','State'])
Coronastate = Coronastate.drop(columns = {'Total Deaths','Death Rate per 100000',"Death Rate per 100K in Last 7 Days"}) 
Coronastate.head()
# Out:
#         State  Total Cases  Abbrev Code
# 0      Alaska        51693  Alaska   AK
# 1     Alabama       443009    Ala.   AL
# 2    Arkansas       284702    Ark.   AR
# 3     Arizona       727895   Ariz.   AZ
# 4  California      3136158  Calif.   CA

# %%
#Obestity import 
df = pd.read_csv('National_Obesity_By_State.csv')
Obesity = pd.DataFrame(df) 
Obesity = Obesity.rename(columns={"NAME":"State"}) 
Obesity.head()
# Out:
#    FID       State  Obesity  SHAPE_Length    SHAPE_Area
# 0    1       Texas     32.4  1.540832e+07  7.672329e+12
# 1    2  California     24.2  1.451870e+07  5.327809e+12
# 2    3    Kentucky     34.6  6.346699e+06  1.128830e+12
# 3    4     Georgia     30.7  5.795596e+06  1.652980e+12
# 4    5   Wisconsin     30.7  6.806782e+06  1.567816e+12

# %%
df1 = pd.read_csv('csvData.csv')
State = pd.DataFrame(df1) 
State.head()
# Out:
#         State  Abbrev Code
# 0     Alabama    Ala.   AL
# 1      Alaska  Alaska   AK
# 2     Arizona   Ariz.   AZ
# 3    Arkansas    Ark.   AR
# 4  California  Calif.   CA

# %%
ObseityFrame = pd.merge(
    Obesity, State, how="left", on=["State", "State"])

# %%
ObseityFrame.rename(columns={"Code": "State","State":"Name","Obesity":"Obesity (BMI)"}) 
ObseityFrame.head()
# Out:
#    FID       State  Obesity  SHAPE_Length    SHAPE_Area  Abbrev Code
# 0    1       Texas     32.4  1.540832e+07  7.672329e+12    Tex.   TX
# 1    2  California     24.2  1.451870e+07  5.327809e+12  Calif.   CA
# 2    3    Kentucky     34.6  6.346699e+06  1.128830e+12     Ky.   KY
# 3    4     Georgia     30.7  5.795596e+06  1.652980e+12     Ga.   GA
# 4    5   Wisconsin     30.7  6.806782e+06  1.567816e+12    Wis.   WI

# %%
FinalFrame = pd.merge(
    ObseityFrame, Coronastate, how="left", on=["State", "State"]) 
ObseityFrame.head()
# Out:
#    FID       State  Obesity  SHAPE_Length    SHAPE_Area  Abbrev Code
# 0    1       Texas     32.4  1.540832e+07  7.672329e+12    Tex.   TX
# 1    2  California     24.2  1.451870e+07  5.327809e+12  Calif.   CA
# 2    3    Kentucky     34.6  6.346699e+06  1.128830e+12     Ky.   KY
# 3    4     Georgia     30.7  5.795596e+06  1.652980e+12     Ga.   GA
# 4    5   Wisconsin     30.7  6.806782e+06  1.567816e+12    Wis.   WI

# %%
ObesityFrame = ObseityFrame.drop(columns=['SHAPE_Length', 'SHAPE_Area','Abbrev','FID']) 
ObesityFrame = ObesityFrame.drop(38)    
ObesityFrame.head()
# Out:
#         State  Obesity Code
# 0       Texas     32.4   TX
# 1  California     24.2   CA
# 2    Kentucky     34.6   KY
# 3     Georgia     30.7   GA
# 4   Wisconsin     30.7   WI

# %%
ObesityFrame= ObesityFrame.rename(columns={"Code": "State","Obesity":"Obesity (BMI)"}) 
ObesityFrame = ObesityFrame.drop([35])

# %%
ObesityFrame.head()
# Out:
#         State  Obesity (BMI) State
# 0       Texas           32.4    TX
# 1  California           24.2    CA
# 2    Kentucky           34.6    KY
# 3     Georgia           30.7    GA
# 4   Wisconsin           30.7    WI

# %%
FinalFrame = pd.merge(
    ObseityFrame, Coronastate, how="left", on=["State", "State"]) 
FinalFrame = FinalFrame.drop(columns=['SHAPE_Length', 'SHAPE_Area','Abbrev_x','Abbrev_y','Code_x','Code_y','FID']) 
FinalFrame = FinalFrame.drop([51,35,38]) 
FinalFrame
# Out:
#              State  Obesity  Total Cases
# 0            Texas     32.4    2246845.0
# 1       California     24.2    3136158.0
# 2         Kentucky     34.6     347836.0
# 3          Georgia     30.7     870828.0
# 4        Wisconsin     30.7     582477.0
# 5           Oregon     30.1     138587.0
# 6         Virginia     29.2     483326.0
# 7        Tennessee     33.8     710427.0
# 8        Louisiana     36.2     385942.0
# 9         New York     25.0     772569.0
# 10        Michigan     31.2     600093.0
# 11           Idaho     28.6     160033.0
# 12         Florida     26.8    1627830.0
# 13          Alaska     29.8      51693.0
# 14         Montana     23.6      91816.0
# 15       Minnesota     26.1     455783.0
# 16        Nebraska     31.4     187793.0
# 17      Washington     26.4     302141.0
# 18            Ohio     29.8     868656.0
# 19        Illinois     30.8    1104763.0
# 20        Missouri     32.4     450414.0
# 21            Iowa     32.1     313515.0
# 22    South Dakota     30.4     107180.0
# 23        Arkansas     34.5     284702.0
# 24     Mississippi     35.6     266598.0
# 25        Colorado     20.2     387462.0
# 26  North Carolina     30.1     723445.0
# 27            Utah     24.5     337264.0
# 28        Oklahoma     33.9     380647.0
# 29         Wyoming     29.0      51022.0
# 30   West Virginia     35.6     115839.0
# 31         Indiana     31.3     613228.0
# 32   Massachusetts     24.3     489298.0
# 33          Nevada     26.7     271897.0
# 34     Connecticut     25.3     243632.0
# 36    Rhode Island     26.0     111754.0
# 37         Alabama     35.6     443009.0
# 39  South Carolina     31.7     421417.0
# 40           Maine     30.0      37708.0
# 41          Hawaii     22.7      24587.0
# 42         Arizona     28.4     727895.0
# 43      New Mexico     28.8     169696.0
# 44        Maryland     28.9     344620.0
# 45        Delaware     29.7      75191.0
# 46    Pennsylvania     30.0     807867.0
# 47          Kansas     34.2     269255.0
# 48         Vermont     25.1      11165.0
# 49      New Jersey     25.6     666951.0
# 50    North Dakota     31.0      97006.0

# %%
# Histogram Plot of Data
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Obesity')
plt.ylabel('Total Cases')
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.006154583499523735

# %%
stats.ttest_ind(x_values, y_values, equal_var=False)
# Out:
# Ttest_indResult(statistic=-6.175268337126128, pvalue=1.3528624574923802e-07)

# %%
FinalFrame = FinalFrame.set_index("State")

# %%
count_chart = FinalFrame.plot(kind='bar', figsize=(10, 11),width=1)

# Set the xlabel and ylabel using class methods
count_chart.set_xlabel("State")
count_chart.set_ylabel("Covid Deaths")


plt.show()
plt.tight_layout() 


count_chart = FinalFrame['Obesity'].plot(kind='bar', figsize=(10, 2),width=1)

# Set the xlabel and ylabel using class methods
count_chart.set_xlabel("State")
count_chart.set_ylabel("Obesity (BMI)")


plt.show()
plt.tight_layout()

# %%
t = np.arange(0.01, 10.0, 0.01)
data1 = np.exp(t)
data2 = np.sin(2 * np.pi * t)

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('time (s)')
ax1.set_ylabel('exp', color=color)
ax1.plot(t, data1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('sin', color=color)  # we already handled the x-label with ax1
ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-a64e0c25ed63> in <module>
# ----> 1 plot = FinalFrame.plot.pie(figsize=(11, 6))
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in pie(self, **kwargs)
#    1415             and not kwargs.get("subplots", False)
#    1416         ):
# -> 1417             raise ValueError("pie requires either y column or 'subplots=True'")
#    1418         return self(kind="pie", **kwargs)
#    1419
#
# ValueError: pie requires either y column or 'subplots=True'
